# %%
import tensorflow as tf
from tensorflow.contrib import rnn
from tensorflow.python.ops import variable_scope
from tensorflow.python.framework import dtypes
import numpy as np
import pandas as pd
import copy
from pprint import pprint
from model_seq2seq import seq2seq
FILE_FOLDER = '../prediction_data/%s'
AFTER_FILE_FOLDER = '../prediction_data/afterAnalysis/%s'

# %% [markdown]
# # Train by past 3 months

# %%
train_data = pd.read_csv(AFTER_FILE_FOLDER % 'aq18_02_04.csv')
train_data[['PM25', 'PM10','O3']] = train_data[['PM25', 'PM10','O3']].\
                                     fillna(train_data[['PM25', 'PM10','O3']].mean())
train_data = train_data[['station_id', 'time', 'PM25', 'PM10', 'O3']]
train_data['PM25'] = train_data['PM25'].astype('int64')
train_data['PM10'] = train_data['PM10'].astype('int64')
train_data['O3'] = train_data['O3'].astype('int64')

# %%
type(train_data['PM25'].max())
# Out:
# numpy.int64

# %%
# train_data.set_index
aq_stations_list = train_data['station_id'].unique().tolist()
len(aq_stations_list)
train_data_copy = train_data.copy()
train_data_copy.set_index(['station_id'],inplace=True)
train_data_copy.head()
# Out:
#                                 time  PM25  PM10  O3
# station_id
# aotizhongxin_aq  2018-01-31 16:00:00    49    82   6
# aotizhongxin_aq  2018-01-31 17:00:00    47    80   5
# aotizhongxin_aq  2018-01-31 18:00:00    46    91   5
# aotizhongxin_aq  2018-01-31 19:00:00    60    95   6
# aotizhongxin_aq  2018-01-31 20:00:00    52    91   5

# %%
def np_sigmoid(x):
    return 1.0 / (1.0 + np.exp(-1 * x))
    
def generate_training_data(station_name,pollution_name):
    current_train_set = []
    batch = 10
    df_part = train_data_copy.loc[station_name]
    data_array = np.array(df_part[pollution_name])
    len_array = len(data_array)
    # 120 + 48
    X = np.array([])
    y = np.array([])
    normalization = {'PM25': train_data['PM25'].max(),
                     'PM10': train_data['PM10'].max(),
                     'O3': train_data['O3'].max()}
    iterate = 0
    for begin_date_i in range(0,len_array - 168):
        iterate += 1
        X = np.append(X, data_array[begin_date_i: begin_date_i + 120])
        y = np.append(y, data_array[begin_date_i + 120: begin_date_i + 168])
        if(iterate % batch == 0):
            current_train_set.append(
                (X/normalization[pollution_name],y/normalization[pollution_name])
            )
            X = np.array([])
            y = np.array([])
#             break
    return current_train_set
current_train_set = generate_training_data('aotizhongxin_aq','PM25')
len(current_train_set)
# Out:
# 63

# %%
def train_model():
    X, y, predict, global_step = seq2seq()
    with tf.variable_scope('loss'):
        output_loss = 0
        for _y, _Y in zip(predict, y):
            output_loss += tf.reduce_mean(tf.pow(_y - _Y, 2))

        l2loss = 0
        for v in tf.trainable_variables():
            if 'Biases_' in v.name or 'Weights_' in v.name:
                l2loss += tf.reduce_mean(tf.nn.l2_loss(v))

        loss = output_loss + 0.003 * l2loss
        # parameter lambda l2 regulaization
    with tf.variable_scope('optimizer'):
        optimizer = tf.contrib.layers.optimize_loss(loss=loss, learning_rate=0.00001,
                global_step=global_step, optimizer='Adam', clip_gradients=2.5)
        # parameter learning_rate clip_gradients
    pollutions = ['PM25', 'PM10', 'O3']
    for aq_station in aq_stations_list:
        for pollution_name in pollutions:
            print(aq_station, pollution_name)
            with tf.Session() as session:
                session.run(tf.global_variables_initializer())
                d = current_train_set
                n = 0
                for batch_set in current_train_set:
                    n += 1
                    x_, y_ = batch_set
                    feed = {X[t]:x_.reshape((-1, 120))[:,t].reshape((-1, 1)) for t in range(120)}
                    feed.update({y[t]: y_.reshape((-1, 48))[:,t].reshape((-1, 1)) for t in range(48)})
                    _, l = session.run([optimizer, loss], feed_dict=feed)
                    
                print("loss after %d iteractions : %.3f" %(n ,l))
                saver = tf.train.Saver()
                save_path = saver.save(session, AFTER_FILE_FOLDER%('NNdata/iteraction_%s_%s' % (aq_station[:-3], pollution_name)))
                print("Checkpoint saved at: ", save_path)
# Out:
# -------------------------------------------
# aotizhongxin_aq PM25
# loss after 63 iteractions : 0.203
# Checkpoint saved at:  ../prediction_data/afterAnalysis/NNdata/iteraction_aotizhongxin_PM25

# %%
def generate(where, which):
    normalization = {'PM25': 1000.0, 'PM10': 3000.0, 'O3': 300}
    batch_size =30
    aq = train_data_copy.loc[where]
    array = np.array(aq[which])
    x = np.array([])
    y = np.array([])
    n = 0
    for i in range(array.shape[0] - 168):
        x_ = array[i: i + 120]
        y_ = array[i + 120: i + 168]
        x = np.append(x, x_)
        y = np.append(y, y_)
        n += 1
        if n % batch_size == 0:
            pprint(x)
            yield x / normalization[which], y / normalization[which]
            x = np.array([])
            y = np.array([])
            n = 0
d = generate('fangshan_aq','PM25')

# %%
len(next(d)[0])
# Out:
# array([16., 26., 20., ..., 15., 11., 15.])
# 3600

# %%
a,b = next(d)

# %%
len(a)
# Out:
# 3600

# %%
FILE_FOLDER = '../prediction_data/%s'
aq = pd.read_csv(FILE_FOLDER%'beijing_201802_201803_aq.csv')
aq[['PM2.5', 'PM10', 'O3']] = aq[['PM2.5', 'PM10', 'O3']].fillna(aq[['PM2.5', 'PM10', 'O3']].mean())
# aq
fs = np.array(aq[aq['stationId'] == 'fangshan_aq']['PM2.5'])

# fs.shape()

x_ = np.expand_dims(fs[0:120], axis=0)
y_ = fs[120:168]

# %%
bj = ['qianmen_aq', 'miyun_aq']
X, y, predict, global_step = seq2seq()
with tf.variable_scope('loss'):
    output_loss = 0
    for _y, _Y in zip(predict, y):
        output_loss += tf.reduce_mean(tf.pow(_y - _Y, 2))

    l2loss = 0
    for v in tf.trainable_variables():
        if 'Biases_' in v.name or 'Weights_' in v.name:
            l2loss += tf.reduce_mean(tf.nn.l2_loss(v))

    loss = output_loss + 0.003 * l2loss
    # parameter lambda l2 regulaization

with tf.variable_scope('optimizer'):
    optimizer = tf.contrib.layers.optimize_loss(loss=loss, learning_rate=0.00001,
            global_step=global_step, optimizer='Adam', clip_gradients=2.5)
    
    # parameter learning_rate clip_gradients
bj_air = ['PM2.5', 'PM10', 'O3']
for where in bj:
    for which in bj_air:
        print('-------------------------------------------')
        print(where, which)
        with tf.Session() as session:
            session.run(tf.global_variables_initializer())
            fs = np.array(aq[aq['stationId'] == where][which])
            x_ = np.expand_dims(fs[0:120], axis=0)
            y_ = fs[120:168]
            n = 0
            while True:
                try:
                    n += 1
                    feed = {X[t]:x_.reshape((-1, 120))[:,t].reshape((-1, 1)) for t in range(120)}
                    feed.update({y[t]: y_.reshape((-1, 48))[:,t].reshape((-1, 1)) for t in range(48)})
                    _, l = session.run([optimizer, loss], feed_dict=feed)
                    if n % 50 == 0:
                        print("loss after %d iteractions : %.3f" %(n ,l))
                        saver = tf.train.Saver()
                        save_path = saver.save(session, FILE_FOLDER%'afterAnalysis/ff/iteraction_%s_%s_%d' % (where[:-3], which, n))
                        print("Checkpoint saved at: ", save_path)
                        
                except:
                    print("loss after %d iteractions : %.3f" %(n ,l))
                    saver = tf.train.Saver()
                    save_path = saver.save(session, 'iteraction%d' % (n))
                    print("Checkpoint saved at: ", save_path)
                    break
# Out:
# -------------------------------------------
# qianmen_aq PM2.5
# loss after 50 iteractions : 143890.391
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_50
# loss after 100 iteractions : 140078.469
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_100
# loss after 150 iteractions : 136179.219
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_150
# loss after 200 iteractions : 132135.156
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_200
# loss after 250 iteractions : 127923.945
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_250
# loss after 300 iteractions : 123536.969
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_300
# loss after 350 iteractions : 118976.031
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_350
# loss after 400 iteractions : 114268.609
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_400
# loss after 450 iteractions : 109472.195
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_450
# loss after 500 iteractions : 104663.641
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_500
# loss after 550 iteractions : 99921.039
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_550
# loss after 600 iteractions : 95322.695
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_600
# loss after 650 iteractions : 90955.641
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_650
# loss after 700 iteractions : 86895.883
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_700
# loss after 750 iteractions : 83175.484
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_750
# loss after 800 iteractions : 79801.578
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_800
# loss after 850 iteractions : 76774.195
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_850
# loss after 900 iteractions : 74077.367
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_900
# loss after 950 iteractions : 71679.734
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_950
# loss after 1000 iteractions : 69539.102
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1000
# loss after 1050 iteractions : 67606.109
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1050
# loss after 1100 iteractions : 65833.234
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1100
# loss after 1150 iteractions : 64188.500
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1150
# loss after 1200 iteractions : 62660.117
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1200
# loss after 1250 iteractions : 61248.660
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1250
# loss after 1300 iteractions : 59954.020
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1300
# loss after 1350 iteractions : 58766.461
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1350
# loss after 1400 iteractions : 57664.590
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1400
# loss after 1450 iteractions : 56615.508
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1450
# loss after 1500 iteractions : 55574.523
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1500
# loss after 1550 iteractions : 54503.363
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1550
# loss after 1600 iteractions : 53374.543
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1600
# loss after 1650 iteractions : 52181.473
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1650
# loss after 1700 iteractions : 50945.285
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1700
# loss after 1750 iteractions : 49793.211
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1750
# loss after 1800 iteractions : 48724.684
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1800
# loss after 1850 iteractions : 47668.133
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1850
# loss after 1900 iteractions : 46588.027
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1900
# loss after 1950 iteractions : 45569.285
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_1950
# loss after 2000 iteractions : 44626.668
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_2000
# loss after 2050 iteractions : 43723.863
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_2050
# loss after 2100 iteractions : 42826.188
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_2100
# loss after 2150 iteractions : 41973.734
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_2150
# loss after 2200 iteractions : 41178.609
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_2200
# loss after 2250 iteractions : 40442.508
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_2250
# loss after 2300 iteractions : 39760.410
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_2300
# loss after 2350 iteractions : 39121.453
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_2350
# loss after 2400 iteractions : 38512.883
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_2400
# loss after 2450 iteractions : 37928.359
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_2450
# loss after 2500 iteractions : 37370.379
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_2500
# loss after 2550 iteractions : 36841.824
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_2550
# loss after 2600 iteractions : 36345.426
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_2600
# loss after 2650 iteractions : 35881.242
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_12900
# loss after 12950 iteractions : 17366.285
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_12950
# loss after 13000 iteractions : 17301.648
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13000
# loss after 13050 iteractions : 17241.447
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13050
# loss after 13100 iteractions : 17183.033
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13100
# loss after 13150 iteractions : 17125.357
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13150
# loss after 13200 iteractions : 17068.434
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13200
# loss after 13250 iteractions : 17012.795
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13250
# loss after 13300 iteractions : 16958.521
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13300
# loss after 13350 iteractions : 16905.119
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13350
# loss after 13400 iteractions : 16852.047
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13400
# loss after 13450 iteractions : 16798.895
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13450
# loss after 13500 iteractions : 16745.146
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13500
# loss after 13550 iteractions : 16690.521
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13550
# loss after 13600 iteractions : 16635.139
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13600
# loss after 13650 iteractions : 16580.312
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13650
# loss after 13700 iteractions : 16526.953
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13700
# loss after 13750 iteractions : 16475.020
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13750
# loss after 13800 iteractions : 16424.025
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13800
# loss after 13850 iteractions : 16373.755
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13850
# loss after 13900 iteractions : 16323.919
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13900
# loss after 13950 iteractions : 16274.392
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_13950
# loss after 14000 iteractions : 16225.093
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14000
# loss after 14050 iteractions : 16175.956
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14050
# loss after 14100 iteractions : 16127.047
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14100
# loss after 14150 iteractions : 16078.399
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14150
# loss after 14200 iteractions : 16029.982
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14200
# loss after 14250 iteractions : 15981.769
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14250
# loss after 14300 iteractions : 15933.549
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14300
# loss after 14350 iteractions : 15885.318
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14350
# loss after 14400 iteractions : 15837.124
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14400
# loss after 14450 iteractions : 15788.914
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14450
# loss after 14500 iteractions : 15740.519
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14500
# loss after 14550 iteractions : 15691.735
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14550
# loss after 14600 iteractions : 15642.332
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14600
# loss after 14650 iteractions : 15591.975
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14650
# loss after 14700 iteractions : 15540.190
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14700
# loss after 14750 iteractions : 15486.457
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14750
# loss after 14800 iteractions : 15430.846
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14800
# loss after 14850 iteractions : 15374.987
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14850
# loss after 14900 iteractions : 15321.096
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14900
# loss after 14950 iteractions : 15269.741
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_14950
# loss after 15000 iteractions : 15220.221
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_15000
# loss after 15050 iteractions : 15171.803
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_15050
# loss after 15100 iteractions : 15124.139
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_15100
# loss after 15150 iteractions : 15077.052
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_15150
# loss after 15200 iteractions : 15030.367
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_15200
# loss after 15250 iteractions : 14984.068
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_15250
# loss after 15300 iteractions : 14938.033
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_15300
# loss after 15350 iteractions : 14891.340
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_15350
# loss after 15400 iteractions : 14843.083
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_15400
# loss after 15450 iteractions : 14795.570
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_15450
# loss after 15500 iteractions : 14749.158
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_15500
# loss after 15550 iteractions : 14703.488
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_15550
# loss after 15600 iteractions : 14658.354
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_15600
# loss after 15650 iteractions : 14613.642
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_15650
# loss after 15700 iteractions : 14569.286
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_15700
# loss after 15750 iteractions : 14525.281
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_15750
# loss after 15800 iteractions : 14481.556
# Checkpoint saved at:  ../prediction_data/afterAnalysis/ff/iteraction_qianmen_PM2.5_15800
# loss after 15845 iteractions : 14443.310
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-5f4ae83dda3f> in <module>
#      36                     feed.update({y[t]: y_.reshape((-1, 48))[:,t].reshape((-1, 1)) for t in range(48)})
# ---> 37                     _, l = session.run([optimizer, loss], feed_dict=feed)
#      38                     if n % 50 == 0:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     886       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 887                          run_metadata_ptr)
#     888       if run_metadata:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1109       results = self._do_run(handle, final_targets, final_fetches,
# -> 1110                              feed_dict_tensor, options, run_metadata)
#    1111     else:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1285       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1286                            run_metadata)
#    1287     else:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1291     try:
# -> 1292       return fn(*args)
#    1293     except errors.OpError as e:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1276       return self._call_tf_sessionrun(
# -> 1277           options, feed_dict, fetch_list, target_list, run_metadata)
#    1278
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1366         self._session, options, feed_dict, fetch_list, target_list,
# -> 1367         run_metadata)
#    1368
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1291     try:
# -> 1292       return fn(*args)
#    1293     except errors.OpError as e:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1276       return self._call_tf_sessionrun(
# -> 1277           options, feed_dict, fetch_list, target_list, run_metadata)
#    1278
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1366         self._session, options, feed_dict, fetch_list, target_list,
# -> 1367         run_metadata)
#    1368
#
# NotFoundError: ; No such file or directory
# 	 [[{{node save_316/SaveV2}} = SaveV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, ..., DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_316/Const_0_0, save_316/SaveV2/tensor_names, save_316/SaveV2/shape_and_slices, Biases_out, Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/bias, Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/kernel, Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/bias, Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/kernel, Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/bias, Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/kernel, Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/bias, Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/kernel, Weights_out, global_step, optimizer/OptimizeLoss/Biases_out/Adam, optimizer/OptimizeLoss/Biases_out/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/bias/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/bias/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/kernel/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/kernel/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/bias/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/bias/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/kernel/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/kernel/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/bias/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/bias/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/kernel/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/kernel/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/bias/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/bias/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/kernel/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/kernel/Adam_1, optimizer/OptimizeLoss/Weights_out/Adam, optimizer/OptimizeLoss/Weights_out/Adam_1, optimizer/OptimizeLoss/beta1_power, optimizer/OptimizeLoss/beta2_power, optimizer/OptimizeLoss/learning_rate)]]
#
# During handling of the above exception, another exception occurred:
#
# NotFoundError                             Traceback (most recent call last)
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state, strip_default_attrs)
#    1432               self.saver_def.save_tensor_name,
# -> 1433               {self.saver_def.filename_tensor_name: checkpoint_file})
#    1434
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     886       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 887                          run_metadata_ptr)
#     888       if run_metadata:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1109       results = self._do_run(handle, final_targets, final_fetches,
# -> 1110                              feed_dict_tensor, options, run_metadata)
#    1111     else:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1285       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1286                            run_metadata)
#    1287     else:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1307         message = error_interpolation.interpolate(message, self._graph)
# -> 1308       raise type(e)(node_def, op, message)
#    1309
#
# NotFoundError: ; No such file or directory
# 	 [[{{node save_316/SaveV2}} = SaveV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, ..., DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_316/Const_0_0, save_316/SaveV2/tensor_names, save_316/SaveV2/shape_and_slices, Biases_out, Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/bias, Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/kernel, Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/bias, Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/kernel, Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/bias, Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/kernel, Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/bias, Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/kernel, Weights_out, global_step, optimizer/OptimizeLoss/Biases_out/Adam, optimizer/OptimizeLoss/Biases_out/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/bias/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/bias/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/kernel/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/kernel/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/bias/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/bias/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/kernel/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/kernel/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/bias/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/bias/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/kernel/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/kernel/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/bias/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/bias/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/kernel/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/kernel/Adam_1, optimizer/OptimizeLoss/Weights_out/Adam, optimizer/OptimizeLoss/Weights_out/Adam_1, optimizer/OptimizeLoss/beta1_power, optimizer/OptimizeLoss/beta2_power, optimizer/OptimizeLoss/learning_rate)]]
#
# Caused by op 'save_316/SaveV2', defined at:
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/asyncio/base_events.py", line 427, in run_forever
#     self._run_once()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/asyncio/base_events.py", line 1440, in _run_once
#     handle._run()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tornado/gen.py", line 1233, in inner
#     self.run()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tornado/gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-36-5f4ae83dda3f>", line 46, in <module>
#     saver = tf.train.Saver()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1094, in __init__
#     self.build()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1106, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1143, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 784, in _build_internal
#     save_tensor = self._AddSaveOps(filename_tensor, saveables)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 284, in _AddSaveOps
#     save = self.save_op(filename_tensor, saveables)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 202, in save_op
#     tensors)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1690, in save_v2
#     shape_and_slices=shape_and_slices, tensors=tensors, name=name)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py", line 488, in new_func
#     return func(*args, **kwargs)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3272, in create_op
#     op_def=op_def)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1768, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# NotFoundError (see above for traceback): ; No such file or directory
# 	 [[{{node save_316/SaveV2}} = SaveV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, ..., DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save_316/Const_0_0, save_316/SaveV2/tensor_names, save_316/SaveV2/shape_and_slices, Biases_out, Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/bias, Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/kernel, Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/bias, Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/kernel, Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/bias, Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/kernel, Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/bias, Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/kernel, Weights_out, global_step, optimizer/OptimizeLoss/Biases_out/Adam, optimizer/OptimizeLoss/Biases_out/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/bias/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/bias/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/kernel/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_0/lstm_cell/kernel/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/bias/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/bias/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/kernel/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn/multi_rnn_cell/cell_1/lstm_cell/kernel/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/bias/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/bias/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/kernel/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_0/lstm_cell/kernel/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/bias/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/bias/Adam_1, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/kernel/Adam, optimizer/OptimizeLoss/Seq2seq/basic_rnn_seq2seq/rnn_decoder/multi_rnn_cell/cell_1/lstm_cell/kernel/Adam_1, optimizer/OptimizeLoss/Weights_out/Adam, optimizer/OptimizeLoss/Weights_out/Adam_1, optimizer/OptimizeLoss/beta1_power, optimizer/OptimizeLoss/beta2_power, optimizer/OptimizeLoss/learning_rate)]]
#
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-5f4ae83dda3f> in <module>
#      45                     print("loss after %d iteractions : %.3f" %(n ,l))
#      46                     saver = tf.train.Saver()
# ---> 47                     save_path = saver.save(session, 'iteraction%d' % (n))
#      48                     print("Checkpoint saved at: ", save_path)
#      49                     break
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py in save(self, sess, save_path, global_step, latest_filename, meta_graph_suffix, write_meta_graph, write_state, strip_default_attrs)
#    1448               "Parent directory of {} doesn't exist, can't save.".format(
#    1449                   save_path))
# -> 1450         raise exc
#    1451
#    1452     if write_meta_graph:
#
# ValueError: Parent directory of iteraction15845 doesn't exist, can't save.

# %%
AFTER_FILE_FOLDER = '/content/drive/My Drive/Colab Notebooks/MS5002/prediction_data/afterAnalysis/%s'

X, y, predict, global_step = seq2seq()
with tf.Session() as session:
    session.run(tf.global_variables_initializer())
    saver = tf.train.Saver()
    saver.restore(session, FILE_FOLDER%'afterAnalysis/ff')
    feed = {X[t]:x_.reshape((-1, 120))[:,t].reshape((-1, 1)) for t in range(120)}
    feed.update({y[t]: np.array([0.0]).reshape((-1, 1)) for t in range(48)})
    p = session.run(predict, feed_dict=feed)
    p = [np.expand_dims(p_, axis=1) for p_ in p]
    p = np.concatenate(p, axis=1).reshape(48)
    print(np.sum(np.abs(p - y_) / (np.abs(p) + np.abs(y_))) / y_.shape[0])
    print(p)
    print(y_)
# Out:
# INFO:tensorflow:Restoring parameters from ../prediction_data/afterAnalysis/ff
# ---------------------------------------------------------------------------
# DataLossError                             Traceback (most recent call last)
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1291     try:
# -> 1292       return fn(*args)
#    1293     except errors.OpError as e:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1276       return self._call_tf_sessionrun(
# -> 1277           options, feed_dict, fetch_list, target_list, run_metadata)
#    1278
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1366         self._session, options, feed_dict, fetch_list, target_list,
# -> 1367         run_metadata)
#    1368
#
# DataLossError: Unable to open table file ../prediction_data/afterAnalysis/ff: Failed precondition: ../prediction_data/afterAnalysis/ff; Is a directory: perhaps your file is in a different file format and you need to use a different restore operator?
# 	 [[{{node save/RestoreV2}} = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_INT32], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save/Const_0_0, save/RestoreV2/tensor_names, save/RestoreV2/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# DataLossError                             Traceback (most recent call last)
# <ipython-input-34-f3a1108e5d21> in <module>
#       5     session.run(tf.global_variables_initializer())
#       6     saver = tf.train.Saver()
# ----> 7     saver.restore(session, FILE_FOLDER%'afterAnalysis/ff')
#       8     feed = {X[t]:x_.reshape((-1, 120))[:,t].reshape((-1, 1)) for t in range(120)}
#       9     feed.update({y[t]: np.array([0.0]).reshape((-1, 1)) for t in range(48)})
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1536       else:
#    1537         sess.run(self.saver_def.restore_op_name,
# -> 1538                  {self.saver_def.filename_tensor_name: save_path})
#    1539     except errors.NotFoundError as err:
#    1540       # There are three common conditions that might cause this error:
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     885     try:
#     886       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 887                          run_metadata_ptr)
#     888       if run_metadata:
#     889         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1108     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1109       results = self._do_run(handle, final_targets, final_fetches,
# -> 1110                              feed_dict_tensor, options, run_metadata)
#    1111     else:
#    1112       results = []
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1284     if handle is None:
#    1285       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1286                            run_metadata)
#    1287     else:
#    1288       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1306           self._config.experimental.client_handles_error_formatting):
#    1307         message = error_interpolation.interpolate(message, self._graph)
# -> 1308       raise type(e)(node_def, op, message)
#    1309
#    1310   def _extend_graph(self):
#
# DataLossError: Unable to open table file ../prediction_data/afterAnalysis/ff: Failed precondition: ../prediction_data/afterAnalysis/ff; Is a directory: perhaps your file is in a different file format and you need to use a different restore operator?
# 	 [[{{node save/RestoreV2}} = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_INT32], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save/Const_0_0, save/RestoreV2/tensor_names, save/RestoreV2/shape_and_slices)]]
#
# Caused by op 'save/RestoreV2', defined at:
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/asyncio/base_events.py", line 427, in run_forever
#     self._run_once()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/asyncio/base_events.py", line 1440, in _run_once
#     handle._run()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tornado/gen.py", line 1233, in inner
#     self.run()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tornado/gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 267, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 534, in execute_request
#     user_expressions, allow_stdin,
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tornado/gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2819, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2845, in _run_cell
#     return runner(coro)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3020, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3185, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-34-f3a1108e5d21>", line 6, in <module>
#     saver = tf.train.Saver()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1094, in __init__
#     self.build()
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1106, in build
#     self._build(self._filename, build_save=True, build_restore=True)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 1143, in _build
#     build_save=build_save, build_restore=build_restore)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 787, in _build_internal
#     restore_sequentially, reshape)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 406, in _AddRestoreOps
#     restore_sequentially)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/training/saver.py", line 854, in bulk_restore
#     return io_ops.restore_v2(filename_tensor, names, slices, dtypes)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1466, in restore_v2
#     shape_and_slices=shape_and_slices, dtypes=dtypes, name=name)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py", line 488, in new_func
#     return func(*args, **kwargs)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3272, in create_op
#     op_def=op_def)
#   File "/Users/haomao/anaconda3/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1768, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# DataLossError (see above for traceback): Unable to open table file ../prediction_data/afterAnalysis/ff: Failed precondition: ../prediction_data/afterAnalysis/ff; Is a directory: perhaps your file is in a different file format and you need to use a different restore operator?
# 	 [[{{node save/RestoreV2}} = RestoreV2[dtypes=[DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_FLOAT, DT_INT32], _device="/job:localhost/replica:0/task:0/device:CPU:0"](_arg_save/Const_0_0, save/RestoreV2/tensor_names, save/RestoreV2/shape_and_slices)]]

# %%
a = [1,2,3,4,5,6,2]
a[:,2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-fe9ee8c49ebd> in <module>
#       1 a = [1,2,3,4,5,6,2]
# ----> 2 a[:,2]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
x_.reshape((-1, 120))[:,4]
# Out:
# array([41.])

# %%
x_.reshape((-1, 120))
# Out:
# array([[49.        , 39.        , 34.        , 34.        , 41.        ,
#         40.        , 36.        , 35.        , 34.        , 37.        ,
#         40.        , 46.        , 47.        , 41.        , 41.        ,
#         43.        , 41.        , 45.        , 38.        , 26.        ,
#         15.        ,  9.        ,  4.        ,  4.        ,  3.        ,
#          6.        ,  6.        ,  5.        ,  5.        ,  5.        ,
#          3.        ,  3.        ,  5.        ,  5.        ,  8.        ,
#          4.        ,  6.        , 13.        ,  8.        ,  6.        ,
#          9.        , 74.85320388,  8.        , 10.        , 11.        ,
#          6.        ,  8.        ,  9.        ,  6.        ,  5.        ,
#          4.        ,  4.        ,  6.        ,  8.        , 10.        ,
#         28.        , 30.        , 34.        , 37.        , 15.        ,
#         16.        , 26.        , 20.        , 17.        , 21.        ,
#          7.        ,  4.        ,  4.        ,  5.        ,  5.        ,
#          7.        ,  5.        ,  5.        ,  4.        ,  5.        ,
#          8.        ,  9.        , 17.        , 34.        , 36.        ,
#         34.        , 34.        , 30.        , 38.        , 40.        ,
#         39.        , 25.        , 24.        , 29.        , 34.        ,
#         32.        , 39.        , 39.        , 74.85320388, 74.85320388,
#          9.        , 10.        ,  6.        ,  6.        ,  3.        ,
#          7.        ,  7.        ,  4.        ,  4.        ,  6.        ,
#          5.        , 10.        , 11.        , 13.        ,  9.        ,
#          8.        ,  7.        , 11.        , 13.        , 74.85320388,
#         28.        , 33.        , 24.        , 31.        , 32.        ]])
